# %%
pip install pandas torch transformers scikit-learn numpy matplotlib
# Out:
# Requirement already satisfied: pandas in c:\stressapp\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: torch in c:\stressapp\venv\lib\site-packages (2.7.0)
# Requirement already satisfied: transformers in c:\stressapp\venv\lib\site-packages (4.52.3)
# Requirement already satisfied: scikit-learn in c:\stressapp\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy in c:\stressapp\venv\lib\site-packages (2.2.5)
# Requirement already satisfied: matplotlib in c:\stressapp\venv\lib\site-packages (3.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\stressapp\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\stressapp\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\stressapp\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in c:\stressapp\venv\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\stressapp\venv\lib\site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\stressapp\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\stressapp\venv\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\stressapp\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\stressapp\venv\lib\site-packages (from torch) (2025.5.1)
# Requirement already satisfied: setuptools in c:\stressapp\venv\lib\site-packages (from torch) (80.7.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\stressapp\venv\lib\site-packages (from transformers) (0.32.2)
# Requirement already satisfied: packaging>=20.0 in c:\stressapp\venv\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\stressapp\venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\stressapp\venv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\stressapp\venv\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\stressapp\venv\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\stressapp\venv\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\stressapp\venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\stressapp\venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\stressapp\venv\lib\site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\stressapp\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\stressapp\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\stressapp\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\stressapp\venv\lib\site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\stressapp\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\stressapp\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\stressapp\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\stressapp\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\stressapp\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\stressapp\venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\stressapp\venv\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\stressapp\venv\lib\site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\stressapp\venv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\stressapp\venv\lib\site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\stressapp\venv\lib\site-packages (from requests->transformers) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import re
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt

# %%
def clean_tweet(text):
    """Bersihkan tweet dari URL, mention, hashtag, emoji, dan karakter khusus."""
    text = re.sub(r"http\S+|www\S+|https\S+", "", text, flags=re.MULTILINE)  # Hapus URL
    text = re.sub(r"@\w+", "", text)  # Hapus mention
    text = re.sub(r"#\w+", "", text)  # Hapus hashtag
    text = re.sub(r"[^\w\s]", "", text)  # Hapus tanda baca
    text = re.sub(r"\d+", "", text)  # Hapus angka
    text = text.lower().strip()  # Ubah ke huruf kecil dan hapus spasi berlebih
    return text

# %%
# --- Fungsi untuk Mendapatkan Embedding IndoBERT ---
def get_indobert_embedding(text, tokenizer, model, device):
    """Menghasilkan embedding IndoBERT untuk teks."""
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=128).to(device)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state[:, 0, :].cpu().numpy()  # Ambil [CLS] token embedding

# %%
# --- Fungsi untuk Klasifikasi Tweet ---
def classify_tweet(tweet, stress_phrases, non_stress_phrases, tokenizer, model, device):
    """Klasifikasi tweet berdasarkan kemiripan dengan frasa stres/tidak stres."""
    cleaned_tweet = clean_tweet(tweet)
    if not cleaned_tweet:
        return "tidak_stres", 0.0  # Default jika tweet kosong setelah pembersihan

    # Dapatkan embedding tweet
    tweet_embedding = get_indobert_embedding(cleaned_tweet, tokenizer, model, device)

    # Dapatkan embedding frasa stres dan tidak stres
    stress_embeddings = [get_indobert_embedding(phrase, tokenizer, model, device) for phrase in stress_phrases]
    non_stress_embeddings = [get_indobert_embedding(phrase, tokenizer, model, device) for phrase in non_stress_phrases]

    # Hitung cosine similarity
    stress_similarities = [cosine_similarity(tweet_embedding, emb)[0][0] for emb in stress_embeddings]
    non_stress_similarities = [cosine_similarity(tweet_embedding, emb)[0][0] for emb in non_stress_embeddings]

    # Ambil similarity maksimum
    max_stress_sim = max(stress_similarities) if stress_similarities else 0
    max_non_stress_sim = max(non_stress_similarities) if non_stress_similarities else 0

    # Tentukan label berdasarkan similarity tertinggi
    if max_stress_sim > max_non_stress_sim:
        return "stres", max_stress_sim
    else:
        return "tidak_stres", max_non_stress_sim

# %%
# --- Setup IndoBERT ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("indobenchmark/indobert-base-p1")
model = AutoModel.from_pretrained("indobenchmark/indobert-base-p1").to(device)

# %%
# Load the dataset
df_stress = pd.read_csv("dataset/real_dataset_stress.csv")

# Filter stress and non-stress phrases
stress_phrases = df_stress[df_stress["kategori"] == "stres"]["text"].tolist()
non_stress_phrases = df_stress[df_stress["kategori"] == "tidak_stres"]["text"].tolist()
df_stress.head(10)
# Out:
#                                                 text kategori
# 0                                       mau mati aja    stres
# 1               kenapa harus berusaha waktu kesepian    stres
# 2    kenapa harus ngerjain tugas waktu tekanan hidup    stres
# 3                  bodoh banget kan jadi malu maluin    stres
# 4          capek banget jadi orang yang selalu tidur    stres
# 5  tiap malam cuma bisa memuaskan orang lain kare...    stres
# 6  rasanya pengen berpikir pas lagi masalah keluarga    stres
# 7              beneran gak kuat lagi buat menghindar    stres
# 8                            muak jadi omongan orang    stres
# 9               udah nangis tapi tetap harapan palsu    stres

# %%
# --- Load Tweet dari CSV ---
file_path = "tweets-data/save_tweets.csv"
df_tweets = pd.read_csv(file_path)
df_tweets.head(10)
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1929866844585726062  Tue Jun 03 11:44:45 +0000 2025               0
# 1  1929660292440772663  Mon Jun 02 22:03:59 +0000 2025               0
# 2  1929660154892767739  Mon Jun 02 22:03:26 +0000 2025               0
# 3  1929566733708538150  Mon Jun 02 15:52:13 +0000 2025               0
# 4  1929565448988733945  Mon Jun 02 15:47:07 +0000 2025               0
# 5  1929565294059544831  Mon Jun 02 15:46:30 +0000 2025               0
# 6  1929565268474302925  Mon Jun 02 15:46:24 +0000 2025               0
# 7  1929442776648749219  Mon Jun 02 07:39:39 +0000 2025               0
# 8  1929442711729226037  Mon Jun 02 07:39:24 +0000 2025               0
# 9  1929309091391807717  Sun Jun 01 22:48:26 +0000 2025               0
#
#                                     full_text               id_str image_url  \
# 0                      abis ulangan lega hehe  1929866844585726062       NaN
# 1     woi takut bangat nih ulangannya susahhh  1929660292440772663       NaN
# 2                baru bangun tidur bngat plss  1929660154892767739       NaN
# 3        pasti nilai nya jelek nih takut plss  1929566733708538150       NaN
# 4  pusing banget plss uts 2 pelajaran susahhh  1929565448988733945       NaN
# 5                                    aaaaaaaa  1929565294059544831       NaN
# 6  gabisa tidur plsss ini materi susah banget  1929565268474302925       NaN
# 7                duh takut jelek nih hasilnya  1929442776648749219       NaN
# 8                 Pusingh banget abis ulangan  1929442711729226037       NaN
# 9    pagi pagi udah diomelin males banget pls  1929309091391807717       NaN
#
#    in_reply_to_screen_name lang  location  quote_count  reply_count  \
# 0                      NaN   in       NaN            0            0
# 1                      NaN   in       NaN            0            0
# 2                      NaN   in       NaN            0            0
# 3                      NaN   in       NaN            0            0
# 4                      NaN   in       NaN            0            0
# 5                      NaN  und       NaN            0            0
# 6                      NaN   in       NaN            0            0
# 7                      NaN   in       NaN            0            0
# 8                      NaN   in       NaN            0            0
# 9                      NaN   in       NaN            0            0
#
#    retweet_count                                          tweet_url  \
# 0              0  https://x.com/undefined/status/192986684458572...
# 1              0  https://x.com/undefined/status/192966029244077...
# 2              0  https://x.com/undefined/status/192966015489276...
# 3              0  https://x.com/undefined/status/192956673370853...
# 4              0  https://x.com/undefined/status/192956544898873...
# 5              0  https://x.com/undefined/status/192956529405954...
# 6              0  https://x.com/undefined/status/192956526847430...
# 7              0  https://x.com/undefined/status/192944277664874...
# 8              0  https://x.com/undefined/status/192944271172922...
# 9              0  https://x.com/undefined/status/192930909139180...
#
#            user_id_str  username
# 0  1865298251311910914       NaN
# 1  1865298251311910914       NaN
# 2  1865298251311910914       NaN
# 3  1865298251311910914       NaN
# 4  1865298251311910914       NaN
# 5  1865298251311910914       NaN
# 6  1865298251311910914       NaN
# 7  1865298251311910914       NaN
# 8  1865298251311910914       NaN
# 9  1865298251311910914       NaN

# %%
# --- Klasifikasi Tweet ---
results = []
for _, row in df_tweets.iterrows():
    tweet = row["full_text"]
    label, similarity = classify_tweet(tweet, stress_phrases, non_stress_phrases, tokenizer, model, device)
    results.append({
        "text": tweet,
        "cleaned_text": clean_tweet(tweet),
        "label": label,
        "similarity_score": similarity,
        "created_at": row["created_at"],
        "user_id": row["user_id_str"]
    })

# %%
# Buat DataFrame dan simpan ke CSV
df_results = pd.DataFrame(results)
df_results.to_csv("tweet_stress_classification_results.csv", index=False)

# %%
# --- Hitung Kesimpulan Akhir ---
stress_count = len(df_results[df_results["label"] == "stres"])
total_tweets = len(df_results)
stress_percentage = (stress_count / total_tweets) * 100 if total_tweets > 0 else 0

# %%
# Tentukan kesimpulan
final_conclusion = "Stres" if stress_percentage >= 50 else "Tidak Stres"

# %%
# --- Visualisasi Pie Chart ---
labels = ["Stres", "Tidak Stres"]
sizes = [stress_count, total_tweets - stress_count]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=140)
plt.title("Proporsi Tweet Stres vs Tidak Stres")
plt.savefig("stress_pie_chart.png")
plt.show()
# Out:
# C:\Users\MyBook Z Series\AppData\Local\Temp\ipykernel_14020\2987961254.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# --- Tampilkan Hasil ---
print(f"\nHasil Analisis Stres dari {total_tweets} Tweet:")
print(f"Jumlah Tweet Stres: {stress_count} ({stress_percentage:.2f}%)")
print(f"Jumlah Tweet Tidak Stres: {total_tweets - stress_count} ({100 - stress_percentage:.2f}%)")
print(f"Kesimpulan Akhir: {final_conclusion}")
# Out:
# Hasil Analisis Stres dari 21 Tweet:
# Jumlah Tweet Stres: 12 (57.14%)
# Jumlah Tweet Tidak Stres: 9 (42.86%)
# Kesimpulan Akhir: Stres

# %%
df_results['clean_text'] = df_results['text'].apply(clean_tweet)

# Tampilkan semua hasil klasifikasi tweet stress
print("\nContoh Hasil Klasifikasi (Semua):")
for i, row in df_results.iterrows():
    print(f"Tweet: {row['clean_text']}")
    print(f"Label: {row['label']} (Similarity: {row['similarity_score']:.4f})")
    print("-" * 50)
# Out:
# Contoh Hasil Klasifikasi (Semua):
# Tweet: abis ulangan lega hehe
# Label: tidak_stres (Similarity: 0.9090)
# --------------------------------------------------
# Tweet: woi takut bangat nih ulangannya susahhh
# Label: stres (Similarity: 0.9121)
# --------------------------------------------------
# Tweet: baru bangun tidur bngat plss
# Label: stres (Similarity: 0.9062)
# --------------------------------------------------
# Tweet: pasti nilai nya jelek nih takut plss
# Label: stres (Similarity: 0.9242)
# --------------------------------------------------
# Tweet: pusing banget plss uts  pelajaran susahhh
# Label: tidak_stres (Similarity: 0.8909)
# --------------------------------------------------
# Tweet: aaaaaaaa
# Label: stres (Similarity: 0.7853)
# --------------------------------------------------
# Tweet: gabisa tidur plsss ini materi susah banget
# Label: stres (Similarity: 0.9343)
# --------------------------------------------------
# Tweet: duh takut jelek nih hasilnya
# Label: stres (Similarity: 0.8312)
# --------------------------------------------------
# Tweet: pusingh banget abis ulangan
# Label: stres (Similarity: 0.9174)
# --------------------------------------------------
# Tweet: pagi pagi udah diomelin males banget pls
# Label: stres (Similarity: 0.7815)
# --------------------------------------------------
# Tweet: dah lah mau tidur ajaa
# Label: tidak_stres (Similarity: 0.9008)
# --------------------------------------------------
# Tweet: woi lah ini pusing bet cape belajar nyaaa
# Label: tidak_stres (Similarity: 0.8651)
# --------------------------------------------------
# Tweet: aaaaa pusing susah banget
# Label: tidak_stres (Similarity: 0.8948)
# --------------------------------------------------
# Tweet: duh susah banget materi ini
# Label: stres (Similarity: 0.9135)
# --------------------------------------------------
# Tweet: yhh kita belajar duluuu
# Label: stres (Similarity: 0.8570)
# --------------------------------------------------
# Tweet: woiii ini rotinya enak banget gila
# Label: tidak_stres (Similarity: 0.7643)
# --------------------------------------------------
# Tweet: eh iya besok ulangan semoga gampang wkwkkw
# Label: stres (Similarity: 0.8913)
# --------------------------------------------------
# Tweet: laperrr makan apa yah siang ini
# Label: tidak_stres (Similarity: 0.8944)
# --------------------------------------------------
# Tweet: mau pamer hehe dapet banyak mutasinya cuy
# Label: stres (Similarity: 0.9203)
# --------------------------------------------------
# Tweet: podhub eps baru agak  tapi ngakak bangat
# Label: tidak_stres (Similarity: 0.9224)
# --------------------------------------------------
# Tweet: hari minggu saatnya turuuu
# Label: tidak_stres (Similarity: 0.8089)
# --------------------------------------------------
